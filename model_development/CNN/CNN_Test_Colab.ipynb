# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import keras
import io

#from google.colab import drive
from sklearn.metrics import confusion_matrix
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
#drive.mount('/drive')
#datapath = '/drive/My Drive/Colab Notebooks/'
#model_path = '/drive/My Drive/Colab Notebooks/'
datapath = './../../data/Train_Test_Data/CNN/Test/'
model_path = './saved_models/'

# %%
Xt1 = np.load(datapath + 'test_cnn_1_X.npy')
Xt2 = np.load(datapath + 'test_cnn_2_X.npy')
Xt3 = np.load(datapath + 'test_cnn_3_X.npy')
Xt4 = np.load(datapath + 'test_cnn_4_X.npy')

# %%
Yt1 = np.load(datapath + 'test_cnn_1_Y.npy')
Yt2 = np.load(datapath + 'test_cnn_2_Y.npy')
Yt3 = np.load(datapath + 'test_cnn_3_Y.npy')
Yt4 = np.load(datapath + 'test_cnn_4_Y.npy')

# %%
# load json and create model
json_file = open(model_path + 'cnn_model_arch.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_path + 'best_model_1.h5')
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy'])
# Out:
# Loaded model from disk

# %%
X_test = np.concatenate((Xt2,Xt3,Xt4))
Y_test = np.concatenate((Yt2,Yt3,Yt4))

cm = confusion_matrix(np.argmax(Y_test,1), np.argmax(loaded_model.predict(X_test),1))
cm = cm.astype(float)

print(cm)

cm[0,:] = np.true_divide(cm[0,:], cm[0,:].sum())
cm[1,:] = np.true_divide(cm[1,:], cm[1,:].sum())
cm[2,:] = np.true_divide(cm[2,:], cm[2,:].sum())


import seaborn as sns

fig, axs = plt.subplots(1, figsize = (8,8))
axs = sns.heatmap(cm, xticklabels=['Up','Unch', 'Down'], 
                  yticklabels=['Up','Unch', 'Down'], annot = True,square=True, 
                  cmap=plt.cm.Blues, annot_kws={"size":16})

axs.set_title("Validation Set 1", fontsize = 15, weight = 'bold')
axs.set_xlabel('Predicted Label', fontsize = 15, style = 'italic')
axs.set_ylabel('True Label', fontsize = 15, style = 'italic')
fig.savefig('CM_Valid1.png')
# Out:
# [[ 3847.   906.  1877.]
#  [21016. 98555. 26607.]
#  [ 1288.   910.  4330.]]

# %%
# load json and create model
json_file = open(model_path + 'cnn_model_arch.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_path + 'best_model_2.h5')
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy'])


X_test = np.concatenate((Xt1,Xt3,Xt4))
Y_test = np.concatenate((Yt1,Yt3,Yt4))

cm = confusion_matrix(np.argmax(Y_test,1), np.argmax(loaded_model.predict(X_test),1))
cm = cm.astype(float)

print(cm)

cm[0,:] = np.true_divide(cm[0,:], cm[0,:].sum())
cm[1,:] = np.true_divide(cm[1,:], cm[1,:].sum())
cm[2,:] = np.true_divide(cm[2,:], cm[2,:].sum())


import seaborn as sns

fig, axs = plt.subplots(1, figsize = (8,8))
axs = sns.heatmap(cm, xticklabels=['Up','Unch', 'Down'], 
                  yticklabels=['Up','Unch', 'Down'], annot = True,square=True, 
                  cmap=plt.cm.Blues, annot_kws={"size":16})

axs.set_title("Validation Set 2", fontsize = 15, weight = 'bold')
axs.set_xlabel('Predicted Label', fontsize = 15, style = 'italic')
axs.set_ylabel('True Label', fontsize = 15, style = 'italic')
fig.savefig('CM_Valid2.png')
# Out:
# Loaded model from disk
# [[  2871.    812.   1148.]
#  [ 24652. 102720.  22412.]
#  [  1033.    963.   2725.]]

# %%
# load json and create model
json_file = open(model_path + 'cnn_model_arch.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_path + 'best_model_3.h5')
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy'])


X_test = np.concatenate((Xt1,Xt2,Xt4))
Y_test = np.concatenate((Yt1,Yt2,Yt4))

cm = confusion_matrix(np.argmax(Y_test,1), np.argmax(loaded_model.predict(X_test),1))
cm = cm.astype(float)

print(cm)

cm[0,:] = np.true_divide(cm[0,:], cm[0,:].sum())
cm[1,:] = np.true_divide(cm[1,:], cm[1,:].sum())
cm[2,:] = np.true_divide(cm[2,:], cm[2,:].sum())


import seaborn as sns

fig, axs = plt.subplots(1, figsize = (8,8))
axs = sns.heatmap(cm, xticklabels=['Up','Unch', 'Down'], 
                  yticklabels=['Up','Unch', 'Down'], annot = True,square=True, 
                  cmap=plt.cm.Blues, annot_kws={"size":16})

axs.set_title("Validation Set 3", fontsize = 15, weight = 'bold')
axs.set_xlabel('Predicted Label', fontsize = 15, style = 'italic')
axs.set_ylabel('True Label', fontsize = 15, style = 'italic')
fig.savefig('CM_Valid3.png')
# Out:
# Loaded model from disk
# [[  3592.    612.   1447.]
#  [ 22770. 100001.  25272.]
#  [  1200.    582.   3860.]]

# %%
# load json and create model
json_file = open(model_path + 'cnn_model_arch.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_path + 'best_model_4.h5')
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(
        optimizer=keras.optimizers.Adam(),
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy'])


X_test = np.concatenate((Xt1,Xt2,Xt3))
Y_test = np.concatenate((Yt1,Yt2,Yt3))

cm = confusion_matrix(np.argmax(Y_test,1), np.argmax(loaded_model.predict(X_test),1))
cm = cm.astype(float)

print(cm)

cm[0,:] = np.true_divide(cm[0,:], cm[0,:].sum())
cm[1,:] = np.true_divide(cm[1,:], cm[1,:].sum())
cm[2,:] = np.true_divide(cm[2,:], cm[2,:].sum())


import seaborn as sns

fig, axs = plt.subplots(1, figsize = (8,8))
axs = sns.heatmap(cm, xticklabels=['Up','Unch', 'Down'], 
                  yticklabels=['Up','Unch', 'Down'], annot = True,square=True, 
                  cmap=plt.cm.Blues, annot_kws={"size":16})

axs.set_title("Validation Set 4", fontsize = 15, weight = 'bold')
axs.set_xlabel('Predicted Label', fontsize = 15, style = 'italic')
axs.set_ylabel('True Label', fontsize = 15, style = 'italic')
fig.savefig('CM_Valid4.png')
# Out:
# Loaded model from disk
# [[ 3204.  1013.  1318.]
#  [21554. 95259. 22289.]
#  [ 1369.   912.  3082.]]
